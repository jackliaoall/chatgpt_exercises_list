# %%
# !pip install yt-dlp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting yt-dlp
#   Downloading yt_dlp-2023.3.4-py2.py3-none-any.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 42.7 MB/s eta 0:00:00
# Collecting mutagen
#   Downloading mutagen-1.46.0-py3-none-any.whl (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 KB 11.8 MB/s eta 0:00:00
# Collecting brotli
#   Downloading Brotli-1.0.9-cp38-cp38-manylinux1_x86_64.whl (357 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.2/357.2 KB 17.4 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from yt-dlp) (2022.12.7)
# Collecting pycryptodomex
#   Downloading pycryptodomex-3.17-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 47.7 MB/s eta 0:00:00
# Collecting websockets
#   Downloading websockets-10.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 KB 5.5 MB/s eta 0:00:00
# Installing collected packages: brotli, websockets, pycryptodomex, mutagen, yt-dlp
# Successfully installed brotli-1.0.9 mutagen-1.46.0 pycryptodomex-3.17 websockets-10.4 yt-dlp-2023.3.4

# %%
import yt_dlp

# 設定選項
ydl_opts = {
    'format': 'bestaudio/best',
    'outtmpl': 'test',
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'mp3',
        'preferredquality': '192',
    }],
}

# 填入影片的URL
url = 'https://www.youtube.com/watch?v=9udVLO947kk'

# 建立 yt_dlp 下載器物件
with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    ydl.download([url])
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=9udVLO947kk
# [youtube] 9udVLO947kk: Downloading webpage
# [youtube] 9udVLO947kk: Downloading android player API JSON
# [youtube] 9udVLO947kk: Downloading MPD manifest
# [info] 9udVLO947kk: Downloading 1 format(s): 251
# [dashsegments] Total fragments: 5
# [download] Destination: test
# [download] 100% of   47.35MiB in 00:00:14 at 3.35MiB/s
# [ExtractAudio] Destination: test.mp3
# Deleting original file test (pass -k to keep)

# %% [markdown]
# 使用pydub 分割音檔

# %%
! pip install pydub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1

# %%
from pydub import AudioSegment

# 載入 MP3 音檔
sound = AudioSegment.from_file('test.mp3', format='mp3')

# 設定每個分割檔案的長度（單位：毫秒）
segment_length = 1000000

# 將音檔分割成多個檔案
for i, chunk in enumerate(sound[::segment_length]):
    # 設定分割檔案的檔名
    chunk.export(f'output_{i}.mp3', format='mp3')

# %% [markdown]
# 使用Whisper API 將音檔轉換成文字

# %%
# !pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting openai
#   Downloading openai-0.27.0-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 KB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.8/dist-packages (from openai) (2.25.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from openai) (4.64.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from openai) (3.8.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.20->openai) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.20->openai) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.20->openai) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.20->openai) (2022.12.7)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->openai) (1.8.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->openai) (22.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->openai) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->openai) (1.3.3)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->openai) (3.0.1)
# Installing collected packages: openai
# Successfully installed openai-0.27.0

# %%
import os
import openai

openai.api_key = ''
audio_file = open("output_0.mp3", "rb")
transcript_0 = openai.Audio.transcribe("whisper-1", audio_file)

# %%
transcript_0.to_dict().get('text')
# Out:
# '我們就開始吧。 那想問一下,有人有在用Rx的subject嗎? 就是在程式碼裡面有在開始用subject的。 那另外一個問題,第一次聽到subject的話,你會覺得它是用來幹什麼的? 那在哪一種情境下面你會聽到subject這個名詞? 因為事實上在Angle的官網裡面提到subject的,我記得次數沒有很多,一兩次而已。然後關於subject通常都是在一些比較進階的使用情境上面才會提到它。 那你知道說,事實上那個output它是subject的一種。 那這件事情,我來找程式碼給你們看。 這邊應該看不到程式碼,我來換一下。 output package code source 你點那個筆應該有,可以點過去。 那筆不是編輯文件嗎? 它有一個雙箭頭,筆或雙箭頭我忘記了。 其中就是連到院士碼。 Hello,我來囉! 所以,看一下我看output。 它有改寫嗎? 好像有改寫,它的始作沒有在這邊。 它的始作沒有放在這邊。 事實上output它是繼承subject來的,所以它的行為像那個emit的部分, 它就,啊我知道了,那個要看event emitter才對。 OK,所以這邊看到了,這邊放大一點。 所以event emitter的部分它是繼承subject來的。 所以像我們常常在送什麼event什麼東西, emitter的話它就是事實上subject的next。 這個就是大概是在angular裡面使用到subject,比較很明確的地方。 事實上subject除了這裡之外還有其他地方。 最常見的做法就是說把subject當作它是一個, 如果你要做multicast的時候通常它都建議使用subject。 OK,好,不管。 所以我們今天介紹什麼是subject,subject它這個東西比較特別。 它是一個,它有兩種身份,它一個是,它本身是一個observable, 然後它也可以同時存在observer的特性。 表示說它本身可以被註冊,然後它也可以拿去註冊其他的observer。 所以它有兩種身份。 然後在,所以它這邊就寫說每一個subject都是一個observable, 然後每一個subject也是一個observer。 那observer通常就會有那三個特性,next, error, and complete。 OK,所以它當然就可以做next, error, and complete這件事情。 然後它也可以被註冊,所以你看這邊的地方那就是subject.subscribe。 OK,所以subject它有這兩種特性。 那subject的種類又有分,總共有三種。 一個是subject,應該說四種啦。 subject本身,你們看看這邊,除了一個單純的subject, 就例如說像這樣子的new出來的subject, 另外一種是behavioral subject,然後還有replace subject跟async subject。 總共有四種subject,各個使用的情境不太一樣, 然後它的行為也不太一樣。 OK,例如說我們以subject來講,subject它是, 基本上它就是一個很單純的東西, 一進起來之後,只要有註冊,在它註冊之後做next, 它都可以收到值。 我們來例如說。 當我a1.next的時候,那我就會收到一個1, 然後相對的我2的時候它就會收到一個2。 當我complete完的時候,我再送任何值,它就會結束, 它會沒有東西。 所以這裡我們就表現出兩種特性, 一個是observer,一個是observer的特性。 OK,那subject它就是這樣子,你只要註冊起來, 它第一次也不會發送任何值, 它也不會去保留任何的資料。 那接下來是另外一種比較常見的東西叫做behavior subject, 那behavior subject這個東西它比較特殊, 它在建立的時候,它需要給它一個預設值, 所以必須要給它一個default value, 不管什麼東西,它一定要給default。 所以default的意思是說當我第一次subscribe的時候, 它就會把它的default value傳給我, 這裡就會有一個default value的部分,就會傳過來。 然後之後的行為就跟一般的subject行為是一模一樣的。 那如果說我多重註冊呢?一樣。 它的行為是當我任何人去做subscribe的時候, 它都會把最後一次發生的值留下來。 意思是什麼?當我傳另外一個值, 那我再做一次subscribe, 那時候我的值應該是什麼?是default value還是second value? 你知道嗎? second吧! 對,是second。 所以它會保留最後一次, 這是behavior subject的效果,它會保留最後一次的結果。 那我不可能每次都subscribe, 因為你看我現在如果說我再做第三次, 那我的值會出現三個,因為我總共有三個人去註冊它。 那你又說它總共被三個人註冊了,所以它會有三個。 那我怎麼取值? behavior subject它有個比較特殊的, 它有額外的一個方法可以取下當下的值叫做gate value。 所以當你下gate value的時候就可以取到你目前保留的最後一個值。 那通常也會有一個叫做gate value啦,這是一樣的東西。 這兩個效果是一樣的。 OK 那還有另外一個東西叫做,其實這個東西subject就有了, 一個叫做subservo。 那問題是為什麼要寫一個叫做.subservo呢? 原因是因為當我回傳出去的時候, 那假設type script我們可以定義它是subject或者是subservo, 所以我們回傳的性別我們可以把它定義成subservo。 那表示說我在外面要使用它的時候, 我就不可以用.next的方式去做任何傳值的動作, 因為它已經被限定它的性別是subservo。 這個是一個比較特殊的東西。 那就是又會多一個這個東西啦。 所以b1就complete。 還是有啦,可是我b1應該是不能next啦。 咦,還是可以耶。 因為我傳值沒有註冊耶,它裡面的值還是保留著。 OK 好,所以,咦,什麼東西? 咦,剛才畫線什麼意思? 好,沒關係。 所以接下來是 不好意思,請問一下喔,那個default value一定要是那種boolean啊string啊這種型態的嗎? string也可以啊,反正我要一個預設值,你要塞什麼東西都可以啊。 塞promise也可以,之類的。 你不能塞promise。 對 咦,那可以塞function嗎? 你塞function幹嘛? 啊,可以塞物件嗎? 啊,可以塞物件啦。 它要塞一個值啦,你要塞一個 塞,你要塞function,塞function然後呢? function as value啊。 我可以試試看啊,可是然後呢? 啊不是first class function了嗎? 啊就function當value算。 我沒試過啊,來試試看。 好 這是replay,不好意思,等一下喔。 重來。 所以 不要跟我抱怨了。 可以啊。 不錯吧,證明教學沒有騙人。 可以做啊。 所以如果你要這樣子做的話,那就要這樣子啊。 OK,OK。 來考驗那個promise喔,來試試看好不好。 我不知道promise可不可以。 啊 promise要怎麼寫?啊我看一下喔。 key.enum.promise function as value 然後say timeout。 可是promise好像聽起來怪怪的。 啊我沒有resolve。 resolve 所以b1.enum.rx.behaviorSubject,然後key,對吧。 我是覺得很奇怪啦。 看起來是可以丟啊,可是很奇怪而已啊。 所以你剛才講的情境應該是你想去呼叫一個AP啊,然後把紙存進去嘛,對不對。 就是我,對,我在想說他這個是要去接link啊,還是怎麼樣使用。 呃,可以舉個情境嗎? 就是通常我看到的範例都是拿behaviorSubject,然後給個預設值,然後點next去用。 對,可是對,所以他如果要串一個API到底是要塞在那個default裡面,還是是在後面。 他要串一個API。 呃,我這邊我這邊有開一個,你所要串一個API是指。 就是他init以後我可能想要去拿某個API的東西回來這樣子。 哦,你要串後面的嘛,對不對。 對對對。 那個是用pipe跟merge map去做串接就可以了。 哦,所以是要串在後面,ok。 因為應該這樣講好了,因為我當我,等下我這邊直接寫一次比較快。 把rtg,任何東西都要subject裡面去,可是很奇怪啊。 然後,不知道為什麼我每次這邊寫他都不認識我的。 完全不懂為什麼他不認識我的。 對,然後最近VSCode也怪怪的,他也會認不出來,不知道為什麼。 很奇怪啊,明明就活著了,他就不認識,莫名其妙。 然後format完之後就ok了,我也完全搞不懂他到底發生什麼事情。 嗯,好,等一下喔,這個串出,有任何使用情境上沒問題就直接隨時發問。 因為subject部分基本上也沒有,他應用其實很,我覺得不困難啦。 他本身不困難,只是說是應用的部分。'

# %%
audio_file = open("output_1.mp3", "rb")
transcript_1 = openai.Audio.transcribe("whisper-1", audio_file)

# %%
transcript_1.to_dict().get('text')
# Out:
# 'Rename file,那個怪怪的,對啊。 所以我先找一個假的API來用,fake,json,placeholder。 然後,他要改網址,他樣式改了耶。 啊,沒關係。 還有兩個。 所以這邊要有個網址。 Gate,post,comment。 所以這邊是什麼?return。 然後, 然後,我需要一個input, 然後, 我想一下喔。 我等一下再重構好了,先這樣子。 所以我這邊當我輸入1,2的時候,他會取值出來。 這邊是會取得不同的comment。 所以那假如說我這邊想要用subject方式處理的話,要怎麼處理? 所以我這邊是query comment, 然後我去建一個subject, new behavior, 然後,這裡需要一個merge name, 所以我預設給他1嘛。 然後,所以說當我, 我beta好了。 Meet 然後我的畫面上面顯示就 所以我現在動作就是我要2的時候要送出來,要更新這邊嘛 對,這是我們剛才講的狀況 所以要怎麼做?它的部分就是會變成Select.query.nextid 這邊可以嗎? OK 等一下 欸?好手沒有反應 Button bind的時間有改到嗎? 什麼意思?喔,這邊沒改到,對 這樣子,2,3 這樣子是你剛才講的狀況嘛對不對? 欸,對 好,所以做法重新再看一下,然後抽出來 我把雜訊拿到後面去 好,所以我這邊有一個query,這邊是負責去傳截止 然後當我subject發生止移動的時候 它會先去,應該是這樣,我畫面進來的時候,因為我畫面上面有個sync 所以它會做第一次註冊,那第一次註冊它取到的值就是1 這邊是1,然後這個1就會變成是這個ID 然後它去取值回傳回來,之後就顯示畫面上面,就長這樣子 所以當我下一次,當我送出另外一個東西的時候 它會重新再跑一次,get post comment 然後它會去把資料取回來 這是我們比較常見在重新撈資料的時候我們會這樣處理 就是用subject或是behave subject來當作我們的類似啟動觸發的控制器 這樣子,這邊是這樣ok嗎? 可以可以 請問一下,就是merge map跟switch map還是有點搞混 在這種情境這兩個的差異是什麼? 如果這邊不用merge map用switch的話 switch map使用情境是當我知道這個post comment有可能會 它的反應時間比較長 然後使用者一直去做這種送出的動作 這要看network才比較準 我要怎麼給你,啊我知道了,我open給你看 然後這邊開network 好,所以假設我這邊按下1的時候 你有沒有看到它這邊跑了一次 對不對,可是我當按多下的時候它是跑很多次 這樣可以嗎?這是用merge map,它不會取消 就是那個1會跑出來的意思 對,你按幾次它就跑幾次 那我把那個什麼,我把網路速度降慢 然後我們再來看它的效果 因為我這樣子我沒有辦法看到它有delay的狀況嘛 所以我把它的速度變慢 它這個反應,這太快了,它一下就回來了 我看一下,我要怎麼,slow 3G還不夠 還是自己加delay在那個裡面 delay沒有用,它要後段的動作才有 像一下,它們要比較長 type一個delay不行嗎? 不行 因為它的switch map是針對這個去做cancel 我來做一次好了,看快一點它不會有什麼效果 沒有,它跑太快了 反正這樣快速講了 switch map是當你想要避免它通知間資料回來的時候打架 那你就是想保留最後一份的時候就使用switch map ok ok 對,可是當你怕使用者連續按兩次low data 那你就用switch map它就可以把第一次在client端取消 它不是server端取消,server端還是被打兩次 client端它是只保留最後一次的資料 然後前面那份資料它就取消了,它就不使用 但是對後端的API來講,它還是被打兩次,它還是會跑兩次 問你一下,你那個get post comment它的型別是什麼? get post comment這個method的回傳值是什麼型別? observable ok,所以merge map回來data還是observable? 這裡到下一個階段這邊就不是了 這邊就是data了 這裡是observable ok 因為merge map它一定要回傳observable 那data呢?data是什麼型別? data,observable啊 data也是observable,ok 因為我沒有subscribe嘛 對對對,ok 所以它這個整體來講都是observable ok,所以不是subject,ok 不是,你只要派完之後基本上都是observable ok 只有在沒有做任何事情的時候它是subject 那像如果假設不是用angular的http get,是用什麼fetch之類的那種 假設回來是一個promise呢? 一樣啊,一樣可以接啊,上禮拜有講吧 上禮拜,反正之前有講過說 你只要你的operator是可以接observable 它就可以接promise 喔,好像有,對,不好意思 所以像front它可以接promise merge map, switch map,contain map 只要是可以接observable的都可以接promise 不用再一個off還是什麼fuck 不用不用不用 不用,所以意思是說假如說我這邊就直接接一個fetch,它也可以啊 因為fetch我記得是promise吧 對啊 這邊也是可以的 試一下喔 fetch是這樣用嗎?我也搞不懂 嗯?等一下,反正大致上意思啦 它就是可以接 裡面它可以retain一個promise 所以它是像這樣子 所以behaviour subject是這樣用的 那replace object我們來看一下它有一個東西叫做replace object 那replace object它是什麼東西? replace object基本上它是 它可以保留你設定的比數 所以它後面也會接一個值 那這個值就是表示說你想要保留的那個 應該是說它buffer的大小吧 那這邊設定3就是我保留最後的 所以假如說設1的話 它的行為就跟那個behaviour subject是一樣的 只是它沒有一個預設值 所以我這時候,它也沒有法律可以用 所以當我next的時候 它是1,然後2的時候是這樣子 然後3是這樣子 所以當我下一個人進來的時候 它會回傳3,最後一筆3給我 這樣網路可以嗎? 這樣有看到畫面嗎? 哈囉 沒畫面喔? 沒有,我剛剛那個網路斷線 這樣有聽到聲音嗎? 有齁,那我繼續囉 好,所以我剛才設1嘛 所以1的行為它就跟behaviour subject是一樣的 那如果說把它設成多一點的話 譬如說我把它設成3 然後R.subscribe R.next 1,2,3,4 所以當我下一次有人subscribe的時候 它會吐最後那三筆資料給他 同時間喔,它不是分次,它是同時間吐三筆 然後最後三筆就是2,3,4這樣子 可以嗎?這是replace subject 那表示什麼?假如說我設一個數字 它是可以當作我可以記錄超遙遠的東西 所以這個是replace subject 它會保留之前的東西 那最後一個是async subject 那async subject它事實上你在平常console.log的時候你是取不到資料的 只有當你complete的時候它才會取到最後一次發生的資料 這是async subject 所以我們就直接看範例了 這個一個async subject 然後它註冊完之後 當我下了一堆next的時候 事實上我不會,這邊我不會console.log任何值出來 只有當我在下complete的時候它才會把最後一次發生'

# %%
transcript = transcript_0.to_dict().get('text') + transcript_1.to_dict().get('text')

# %%
transcript
# Out:
# '我們就開始吧。 那想問一下,有人有在用Rx的subject嗎? 就是在程式碼裡面有在開始用subject的。 那另外一個問題,第一次聽到subject的話,你會覺得它是用來幹什麼的? 那在哪一種情境下面你會聽到subject這個名詞? 因為事實上在Angle的官網裡面提到subject的,我記得次數沒有很多,一兩次而已。然後關於subject通常都是在一些比較進階的使用情境上面才會提到它。 那你知道說,事實上那個output它是subject的一種。 那這件事情,我來找程式碼給你們看。 這邊應該看不到程式碼,我來換一下。 output package code source 你點那個筆應該有,可以點過去。 那筆不是編輯文件嗎? 它有一個雙箭頭,筆或雙箭頭我忘記了。 其中就是連到院士碼。 Hello,我來囉! 所以,看一下我看output。 它有改寫嗎? 好像有改寫,它的始作沒有在這邊。 它的始作沒有放在這邊。 事實上output它是繼承subject來的,所以它的行為像那個emit的部分, 它就,啊我知道了,那個要看event emitter才對。 OK,所以這邊看到了,這邊放大一點。 所以event emitter的部分它是繼承subject來的。 所以像我們常常在送什麼event什麼東西, emitter的話它就是事實上subject的next。 這個就是大概是在angular裡面使用到subject,比較很明確的地方。 事實上subject除了這裡之外還有其他地方。 最常見的做法就是說把subject當作它是一個, 如果你要做multicast的時候通常它都建議使用subject。 OK,好,不管。 所以我們今天介紹什麼是subject,subject它這個東西比較特別。 它是一個,它有兩種身份,它一個是,它本身是一個observable, 然後它也可以同時存在observer的特性。 表示說它本身可以被註冊,然後它也可以拿去註冊其他的observer。 所以它有兩種身份。 然後在,所以它這邊就寫說每一個subject都是一個observable, 然後每一個subject也是一個observer。 那observer通常就會有那三個特性,next, error, and complete。 OK,所以它當然就可以做next, error, and complete這件事情。 然後它也可以被註冊,所以你看這邊的地方那就是subject.subscribe。 OK,所以subject它有這兩種特性。 那subject的種類又有分,總共有三種。 一個是subject,應該說四種啦。 subject本身,你們看看這邊,除了一個單純的subject, 就例如說像這樣子的new出來的subject, 另外一種是behavioral subject,然後還有replace subject跟async subject。 總共有四種subject,各個使用的情境不太一樣, 然後它的行為也不太一樣。 OK,例如說我們以subject來講,subject它是, 基本上它就是一個很單純的東西, 一進起來之後,只要有註冊,在它註冊之後做next, 它都可以收到值。 我們來例如說。 當我a1.next的時候,那我就會收到一個1, 然後相對的我2的時候它就會收到一個2。 當我complete完的時候,我再送任何值,它就會結束, 它會沒有東西。 所以這裡我們就表現出兩種特性, 一個是observer,一個是observer的特性。 OK,那subject它就是這樣子,你只要註冊起來, 它第一次也不會發送任何值, 它也不會去保留任何的資料。 那接下來是另外一種比較常見的東西叫做behavior subject, 那behavior subject這個東西它比較特殊, 它在建立的時候,它需要給它一個預設值, 所以必須要給它一個default value, 不管什麼東西,它一定要給default。 所以default的意思是說當我第一次subscribe的時候, 它就會把它的default value傳給我, 這裡就會有一個default value的部分,就會傳過來。 然後之後的行為就跟一般的subject行為是一模一樣的。 那如果說我多重註冊呢?一樣。 它的行為是當我任何人去做subscribe的時候, 它都會把最後一次發生的值留下來。 意思是什麼?當我傳另外一個值, 那我再做一次subscribe, 那時候我的值應該是什麼?是default value還是second value? 你知道嗎? second吧! 對,是second。 所以它會保留最後一次, 這是behavior subject的效果,它會保留最後一次的結果。 那我不可能每次都subscribe, 因為你看我現在如果說我再做第三次, 那我的值會出現三個,因為我總共有三個人去註冊它。 那你又說它總共被三個人註冊了,所以它會有三個。 那我怎麼取值? behavior subject它有個比較特殊的, 它有額外的一個方法可以取下當下的值叫做gate value。 所以當你下gate value的時候就可以取到你目前保留的最後一個值。 那通常也會有一個叫做gate value啦,這是一樣的東西。 這兩個效果是一樣的。 OK 那還有另外一個東西叫做,其實這個東西subject就有了, 一個叫做subservo。 那問題是為什麼要寫一個叫做.subservo呢? 原因是因為當我回傳出去的時候, 那假設type script我們可以定義它是subject或者是subservo, 所以我們回傳的性別我們可以把它定義成subservo。 那表示說我在外面要使用它的時候, 我就不可以用.next的方式去做任何傳值的動作, 因為它已經被限定它的性別是subservo。 這個是一個比較特殊的東西。 那就是又會多一個這個東西啦。 所以b1就complete。 還是有啦,可是我b1應該是不能next啦。 咦,還是可以耶。 因為我傳值沒有註冊耶,它裡面的值還是保留著。 OK 好,所以,咦,什麼東西? 咦,剛才畫線什麼意思? 好,沒關係。 所以接下來是 不好意思,請問一下喔,那個default value一定要是那種boolean啊string啊這種型態的嗎? string也可以啊,反正我要一個預設值,你要塞什麼東西都可以啊。 塞promise也可以,之類的。 你不能塞promise。 對 咦,那可以塞function嗎? 你塞function幹嘛? 啊,可以塞物件嗎? 啊,可以塞物件啦。 它要塞一個值啦,你要塞一個 塞,你要塞function,塞function然後呢? function as value啊。 我可以試試看啊,可是然後呢? 啊不是first class function了嗎? 啊就function當value算。 我沒試過啊,來試試看。 好 這是replay,不好意思,等一下喔。 重來。 所以 不要跟我抱怨了。 可以啊。 不錯吧,證明教學沒有騙人。 可以做啊。 所以如果你要這樣子做的話,那就要這樣子啊。 OK,OK。 來考驗那個promise喔,來試試看好不好。 我不知道promise可不可以。 啊 promise要怎麼寫?啊我看一下喔。 key.enum.promise function as value 然後say timeout。 可是promise好像聽起來怪怪的。 啊我沒有resolve。 resolve 所以b1.enum.rx.behaviorSubject,然後key,對吧。 我是覺得很奇怪啦。 看起來是可以丟啊,可是很奇怪而已啊。 所以你剛才講的情境應該是你想去呼叫一個AP啊,然後把紙存進去嘛,對不對。 就是我,對,我在想說他這個是要去接link啊,還是怎麼樣使用。 呃,可以舉個情境嗎? 就是通常我看到的範例都是拿behaviorSubject,然後給個預設值,然後點next去用。 對,可是對,所以他如果要串一個API到底是要塞在那個default裡面,還是是在後面。 他要串一個API。 呃,我這邊我這邊有開一個,你所要串一個API是指。 就是他init以後我可能想要去拿某個API的東西回來這樣子。 哦,你要串後面的嘛,對不對。 對對對。 那個是用pipe跟merge map去做串接就可以了。 哦,所以是要串在後面,ok。 因為應該這樣講好了,因為我當我,等下我這邊直接寫一次比較快。 把rtg,任何東西都要subject裡面去,可是很奇怪啊。 然後,不知道為什麼我每次這邊寫他都不認識我的。 完全不懂為什麼他不認識我的。 對,然後最近VSCode也怪怪的,他也會認不出來,不知道為什麼。 很奇怪啊,明明就活著了,他就不認識,莫名其妙。 然後format完之後就ok了,我也完全搞不懂他到底發生什麼事情。 嗯,好,等一下喔,這個串出,有任何使用情境上沒問題就直接隨時發問。 因為subject部分基本上也沒有,他應用其實很,我覺得不困難啦。 他本身不困難,只是說是應用的部分。Rename file,那個怪怪的,對啊。 所以我先找一個假的API來用,fake,json,placeholder。 然後,他要改網址,他樣式改了耶。 啊,沒關係。 還有兩個。 所以這邊要有個網址。 Gate,post,comment。 所以這邊是什麼?return。 然後, 然後,我需要一個input, 然後, 我想一下喔。 我等一下再重構好了,先這樣子。 所以我這邊當我輸入1,2的時候,他會取值出來。 這邊是會取得不同的comment ...

# %% [markdown]
# 使用 ChatGPT API 摘要文章

# %%
transcript_ary = []

ret = ''
for script in transcript.split():
    ret = ret + ' ' + script
    if len(ret) > 1000:
        transcript_ary.append(ret)
        ret = ''
transcript_ary.append(ret)

# %%
len(transcript_ary)
# Out:
# 7

# %%
result_ary = []

for t in transcript_ary:
    completion = openai.ChatCompletion.create(
      model="gpt-3.5-turbo",
      messages=[
        {"role": "system", "content": "請你成為文章摘要的小幫手，摘要以下文字，以繁體中文輸出"},
        {"role": "user", "content": t}
      ]
    )

    result_ary.append(completion.choices[0].message)

# %%
len(result_ary)
# Out:
# 7

# %%
result_ary[0].get('content')
# Out:
# '本文介紹了Rx的subject，它是一種特殊的observable，同時也有observer的特性，可以註冊其他的observer。在Angular中，output也是繼承自subject的一種，可以用來發送事件。通常在做multicast的時候也建議使用subject。在本文中，作者講解了subject的基本特性，以及它的身份是observable和observer，可以使用next、error和complete等方法。'

# %%
for res in result_ary:
    print()
    print(res.get('content'))
# Out:
# 本文介紹了Rx的subject，它是一種特殊的observable，同時也有observer的特性，可以註冊其他的observer。在Angular中，output也是繼承自subject的一種，可以用來發送事件。通常在做multicast的時候也建議使用subject。在本文中，作者講解了subject的基本特性，以及它的身份是observable和observer，可以使用next、error和complete等方法。
#
# 本文介紹了RxJS中的Subject，它是一個可以註冊、發送值的物件，可以分為四種類型：普通的Subject、BehaviorSubject、ReplaySubject和AsyncSubject。其中BehaviorSubject需要在建立時指定一個預設值，並且可以保留最後一次發送的值。除了普通的Subject外，其他種類的行為都有一些特別之處，需要特別注意。
#
# 本文介紹了RxJS中的BehaviorSubject和Subservo的使用方法，以及如何設置預設值和使用Promise等不同型態作為預設值。其中提到，BehaviorSubject通過gate value可以取得當前保存的最後一個值，Subservo則限定了其性質。作者透過範例展示了如何運用這些知識。
#
# 本段文字內容在技術層面討論了 Promise, rxjs 的 behaviorSubject 等相關的語法使用，並且提到了串接 API 和使用 rxjs 做狀態管理的相關概念。文章中也有一些個人在實作的過程中所遇到的困難以及解決方案的思路。其中也提到了需要改網址時所遇到的問題以及相關的處理方式。
#
# 本文介紹了在使用 RxJS 時，如何透過 Subject 或 BehaviorSubject 控制流程，以及 mergeMap 與 switchMap 的差異。作者透過一個範例來演示如何在畫面上按下按鈕後，使用 RxJS 的流程控制函數去發送 API 請求，並在請求返回後更新畫面上的資料。此外，作者也針對 switchMap 與 mergeMap 的使用情境進行了解說。最後，作者也提到了如何透過瀏覽器的開發工具調整網速，以測試程式在慢網路情況下的表現。
#
# 文章討論了在使用Angular中的RxJS操作符時，避免多次通知的方法。其中SwitchMap可用於保留最後一份資料，避免過程中的通知。而MergeMap則回傳Observable，Data也是Observable，若使用Fetch等Promise型別，也可以接收Observable操作符，不必使用off等操作。
#
# 該文介紹了四種不同的 RxJS Subjects，包括 BehaviorSubject、ReplaySubject、AsyncSubject 和 Subject。其中 BehaviorSubject 可以保留最後一個值並且有預設值，ReplaySubject 可以保留一定數量的值，AsyncSubject 取最後一個值，只有在 complete 後才會傳值。而 Subject 則是簡單的 Subject。
